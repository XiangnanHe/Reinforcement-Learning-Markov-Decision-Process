# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

#from pivottablejs import pivot_ui
import pandas as pd

# %%
#df = pd.read_csv("Easy Policy.csv")
#hard_df = pd.DataFrame.from_csv("hard_data.csv").transpose()
#df = pd.DataFrame.from_csv("Easy mine robot reward 200.csv").transpose()
#df_time =pd.DataFrame.from_csv("Easy mine robot time 200.csv").transpose()
#df_action = pd.DataFrame.from_csv("Easy mine robot action 200.csv").transpose()

df = pd.DataFrame.from_csv("Easy mine robot reward 200.csv").transpose()
df_time =pd.DataFrame.from_csv("Easy mine robot time 200.csv").transpose()
df_action = pd.DataFrame.from_csv("Easy mine robot action 200.csv").transpose()

hdf = pd.DataFrame.from_csv("Hard nursing robot reward 500.csv").transpose()
hdf_time =pd.DataFrame.from_csv("Hard nursing robot time 500.csv").transpose()
hdf_action = pd.DataFrame.from_csv("Hard nursing robot action 500.csv").transpose()

# %%
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

#df1 = pd.DataFrame.from_csv('Easy Value.csv')
#df2 = pd.DataFrame.from_csv('Easy Policy.csv')
df1 = pd.DataFrame.from_csv('size Value.csv')
df2 = pd.DataFrame.from_csv('size Policy.csv')
df3 = pd.DataFrame.from_csv('size Q-Learning L0.1 E0.5.csv')
ax = df1.plot(x = ['shape'], y=['iteration'])
ax2 = df2.plot(x = ['shape'],y = ['iteration'], ax = ax)
ax3 = df3.plot(x = ['shape'],y = ['iteration'], ax = ax)

ax3.set_ylim(-20,3600)
ax3.set_xlim(0, 30)
blue_line = mlines.Line2D([], [], color = '#1f77b4', label = 'Size Value iteration')
yellow_line = mlines.Line2D([], [], color = '#ff7f0e', label = 'Size Policy iteration')
green_line = mlines.Line2D([], [], color = '#2ca02c', label = 'Size Q-learning L0.1 E0.5 iteration')
plt.legend(handles = [blue_line, yellow_line, green_line])
plt.ylabel('iteration')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

#df1 = pd.DataFrame.from_csv('Easy Value.csv')
#df2 = pd.DataFrame.from_csv('Easy Policy.csv')
df1 = pd.DataFrame.from_csv('Hard Value.csv')
df2 = pd.DataFrame.from_csv('Hard Policy.csv')
ax = df1.plot(y=['reward'])
ax2 = df2.plot(y = ['reward'], ax = ax)

ax2.set_ylim(-20,100)

blue_line = mlines.Line2D([], [], color = '#1f77b4', label = 'Easy Value Reward')
yellow_line = mlines.Line2D([], [], color = '#ff7f0e', label = 'Easy Policy Reward')

plt.legend(handles = [blue_line, yellow_line])
plt.show()

# %%
#df1 = pd.DataFrame.from_csv('Easy Value.csv')
#df2 = pd.DataFrame.from_csv('Easy Policy.csv')
df1 = pd.DataFrame.from_csv('Hard Value.csv')
df2 = pd.DataFrame.from_csv('Hard Policy.csv')
ax = df1.plot(y=['time'])
ax2 = df2.plot(y = ['time'], ax=ax)
ax2.set_ylim(0,0.8)

blue_line = mlines.Line2D([], [], color = '#1f77b4', label = 'Easy Value Time')
yellow_line = mlines.Line2D([], [], color = '#ff7f0e', label = 'Easy Policy Time')
plt.legend(handles = [blue_line, yellow_line])
plt.ylabel('time(s)')
plt.show()

# %%
#df1 = pd.DataFrame.from_csv('Easy Value.csv')
#df2 = pd.DataFrame.from_csv('Easy Policy.csv')
df1 = pd.DataFrame.from_csv('Hard Value.csv')
df2 = pd.DataFrame.from_csv('Hard Policy.csv')
ax = df1.plot(y=['steps'])
ax2 = df2.plot(y = ['steps'], ax=ax)
ax2.set_ylim(0,150)
#ax2.set_xlim(0,25)
blue_line = mlines.Line2D([], [], color = '#1f77b4', label = 'Easy Value Steps')
yellow_line = mlines.Line2D([], [], color = '#ff7f0e', label = 'Easy Policy Steps')
plt.legend(handles = [blue_line, yellow_line])
#plt.ylabel('time(s)')
plt.show()

# %%
#df1 = pd.DataFrame.from_csv('Easy Value.csv')
#df2 = pd.DataFrame.from_csv('Easy Policy.csv')
df1 = pd.DataFrame.from_csv('Hard Value.csv')
df2 = pd.DataFrame.from_csv('Hard Policy.csv')
ax = df1.plot(y=['convergence'])
ax2 = df2.plot(y = ['convergence'], ax=ax)
ax2.set_ylim(-10,100)

blue_line = mlines.Line2D([], [], color = '#1f77b4', label = 'Easy Value Convergence')
yellow_line = mlines.Line2D([], [], color = '#ff7f0e', label = 'Easy Policy Convergence')
plt.legend(handles = [blue_line, yellow_line])
#plt.ylabel('time(s)')
plt.show()

# %%
hdf.info()
#v_policy = pd.read_csv("harder_optimal_value", header=None)
#p_policy = pd.read_csv("harder_optimal_policy", header=None)
#q_policy = pd.read_csv("harder_optimal_q", header=None)

#print "Value Iteration Optimal Policy"
#print v_policy
#print "Policy Iteration Optimal Policy"
#print p_policy
#print "Q-Learning Optimal Policy"
#print q_policy
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, 1 to 500
# Data columns (total 3 columns):
# Value Iteration Reward     500 non-null float64
# Policy Iteration Reward    500 non-null float64
# Q Learning Reward          500 non-null float64
# dtypes: float64(3)
# memory usage: 15.6+ KB

# %%
#p_policy[p_policy == q_policy] = 0
#p_policy[p_policy != 0] = 1
#print "Value Iteration Optimal Policy"
#print v_policy
#print "Policy Iteration vs Q-learning Diff"
#print p_policy

# %%
df1 = pd.DataFrame.from_csv('Hard Q-Learning L 0.99 q 100.0 E 0.1.csv')
df2 = pd.DataFrame.from_csv('Hard Q-Learning L 0.99 q 100.0 E 0.5.csv')
df3 = pd.DataFrame.from_csv('Hard Q-Learning L 0.99 q 100.0 E 0.9.csv')
#df4 = pd.DataFrame.from_csv('Easy Q-Learning L 0.10 q 0.0 E 0.1.csv')
#df5 = pd.DataFrame.from_csv('Easy Q-Learning L 0.10 q 0.0 E 0.4.csv')
#df6 = pd.DataFrame.from_csv('Easy Q-Learning L 0.10 q 0.0 E 0.7.csv')
#df7 = pd.DataFrame.from_csv('Easy Q-Learning L 0.10 q 100.0 E 0.1.csv')
#df8 = pd.DataFrame.from_csv('Easy Q-Learning L 0.10 q 100.0 E 0.3.csv')
#df9 = pd.DataFrame.from_csv('Easy Q-Learning L 0.10 q 100.0 E 0.5.csv')
#df10 = pd.DataFrame.from_csv('Easy Q-Learning L 0.99 q -100.0 E 0.1.csv')
#df11 = pd.DataFrame.from_csv('Easy Q-Learning L 0.99 q -100.0 E 0.3.csv')
#df12 = pd.DataFrame.from_csv('Easy Q-Learning L 0.99 q -100.0 E 0.5.csv')
#df13 = pd.DataFrame.from_csv('Easy Q-Learning L 0.99 q 0.0 E 0.1.csv')
#df14 = pd.DataFrame.from_csv('Easy Q-Learning L 0.99 q 0.0 E 0.4.csv')
#df15 = pd.DataFrame.from_csv('Easy Q-Learning L 0.99 q 0.0 E 0.7.csv')
#df16 = pd.DataFrame.from_csv('Easy Q-Learning L 0.99 q 100.0 E 0.1.csv')
#df17 = pd.DataFrame.from_csv('Easy Q-Learning L 0.99 q 100.0 E 0.3.csv')
#df18 = pd.DataFrame.from_csv('Easy Q-Learning L 0.99 q 100.0 E 0.5.csv')


ax1 = df1.plot(y=['convergence'])
ax2 = df2.plot(y = ['convergence'], ax=ax1)
ax3 = df3.plot(y = ['convergence'], ax=ax1)
#ax4 = df4.plot(y = ['convergence'])
#ax5 = df5.plot(y = ['convergence'], ax=ax4)
#ax6 = df6.plot(y = ['convergence'], ax=ax4)
#ax7 = df7.plot(y = ['time'], ax=ax1)
#ax8 = df8.plot(y = ['time'], ax=ax1)
#ax9 = df9.plot(y = ['time'], ax=ax1)
#ax10 = df10.plot(y = ['time'], ax=ax1)
#ax11 = df11.plot(y = ['time'], ax=ax1)
#ax12 = df12.plot(y = ['time'], ax=ax1)
#ax13 = df13.plot(y = ['steps'])
#ax13 = df13.plot(y = ['time'], ax=ax1)
#ax14 = df14.plot(y = ['steps'], ax=ax13)
#ax15 = df15.plot(y = ['steps'], ax=ax13)
#ax16 = df16.plot(y = ['time'], ax=ax1)
#ax17 = df17.plot(y = ['time'], ax=ax1)
#ax18 = df18.plot(y = ['time'], ax=ax1)

ax3.set_xlim(0,200)
ax3.set_ylim(-0, 30)
#L=plt.legend(bbox_to_anchor=(1.1, 1.05), title = 'Legend')
L=plt.legend()
L.get_texts()[0].set_text('L 0.99 q 100.0 E 0.1')
L.get_texts()[1].set_text('L 0.99 q 100.0 E 0.5')
L.get_texts()[2].set_text('L 0.99 q 100.0 E 0.9')
#L.get_texts()[0].set_text('L 0.1 q 0.0 E 0.1')
#L.get_texts()[1].set_text('L 0.1 q 0.0 E 0.4')
#L.get_texts()[2].set_text('L 0.1 q 0.0 E 0.7')
#L.get_texts()[6].set_text('L 0.1 q 100.0 E 0.1')
#L.get_texts()[7].set_text('L 0.1 q 100.0 E 0.3')
#L.get_texts()[8].set_text('L 0.1 q 100.0 E 0.5')
#L.get_texts()[9].set_text('L 0.9 q -100.0 E 0.1')
#L.get_texts()[10].set_text('L 0.9 q -100.0 E 0.3')
#L.get_texts()[11].set_text('L 0.9 q -100.0 E 0.5')
#L.get_texts()[0].set_text('L 0.99 q 0.0 E 0.1')
#L.get_texts()[1].set_text('L 0.99 q 0.0 E 0.4')
#L.get_texts()[2].set_text('L 0.99 q 0.0 E 0.7')
#L.get_texts()[15].set_text('L 0.9 q 100.0 E 0.1')
#L.get_texts()[16].set_text('L 0.9 q 100.0 E 0.3')
#L.get_texts()[17].set_text('L 0.9 q 100.0 E 0.5')





#blue_line = mlines.Line2D([], [], color = '#1f77b4', label = 'Easy Value Steps')
#yellow_line = mlines.Line2D([], [], color = '#ff7f0e', label = 'Easy Policy Steps')
#plt.legend(handles = [blue_line, yellow_line])
plt.ylabel('convergence')
plt.show()

# %%
ax1 = df1.plot(y=['steps'])
ax2 = df2.plot(y = ['steps'], ax=ax1)
ax3 = df3.plot(y = ['steps'], ax=ax1)
ax4 = df4.plot(y = ['steps'], ax=ax1)
ax5 = df5.plot(y = ['steps'], ax=ax1)
ax6 = df6.plot(y = ['steps'], ax=ax1)
#ax7 = df7.plot(y = ['steps'], ax=ax1)
#ax8 = df8.plot(y = ['steps'], ax=ax1)
#ax9 = df9.plot(y = ['steps'], ax=ax1)
#ax10 = df10.plot(y = ['steps'], ax=ax1)
#ax11 = df11.plot(y = ['steps'], ax=ax1)
#ax12 = df12.plot(y = ['steps'], ax=ax1)
#ax13 = df13.plot(y = ['steps'], ax=ax1)
#ax14 = df14.plot(y = ['steps'], ax=ax1)
#ax15 = df15.plot(y = ['steps'], ax=ax1)
#ax16 = df16.plot(y = ['steps'], ax=ax1)
#ax17 = df17.plot(y = ['steps'], ax=ax1)
#ax18 = df18.plot(y = ['steps'], ax=ax1)

ax6.set_xlim(0,200)
ax6.set_ylim(0,50)

#L=plt.legend(bbox_to_anchor=(1.1, 1.05), title = 'Legend')
L=plt.legend()
L.get_texts()[0].set_text('L 0.1 q -100.0 E 0.1')
L.get_texts()[1].set_text('L 0.1 q -100.0 E 0.3')
L.get_texts()[2].set_text('L 0.1 q -100.0 E 0.5')
L.get_texts()[3].set_text('L 0.1 q 0.0 E 0.1')
L.get_texts()[4].set_text('L 0.1 q 0.0 E 0.3')
L.get_texts()[5].set_text('L 0.1 q 0.0 E 0.5')
#L.get_texts()[6].set_text('L 0.1 q 100.0 E 0.1')
#L.get_texts()[7].set_text('L 0.1 q 100.0 E 0.3')
#L.get_texts()[8].set_text('L 0.1 q 100.0 E 0.5')
#L.get_texts()[9].set_text('L 0.9 q -100.0 E 0.1')
#L.get_texts()[10].set_text('L 0.9 q -100.0 E 0.3')
#L.get_texts()[11].set_text('L 0.9 q -100.0 E 0.5')
#L.get_texts()[12].set_text('L 0.9 q 0.0 E 0.1')
#L.get_texts()[13].set_text('L 0.9 q 0.0 E 0.3')
#L.get_texts()[14].set_text('L 0.9 q 0.0 E 0.5')
#L.get_texts()[15].set_text('L 0.9 q 100.0 E 0.1')
#L.get_texts()[16].set_text('L 0.9 q 100.0 E 0.3')
#L.get_texts()[17].set_text('L 0.9 q 100.0 E 0.5')

# %%
f1 = df.plot(y=['Value Iteration Reward','Policy Iteration Reward','Q Learning Reward'])
f1.set_ylim(0, 100)
f1.set_xlim(0,50)
f2 = df_time.plot(y=['Value Iteration Time','Policy Iteration Time','Q Learning Time'])
f2.set_ylim(-10, 80)
f2.set_xlim(0,50)

f3 = df_action.plot(y=['Value Iteration Action','Policy Iteration Action','Q Learning Action'])
f3.set_ylim(0, 300)
f3.set_xlim(0,50)
# Out:
# (0, 50)

# %%
#df.plot(y=['Value Iteration Rewards','Policy Iteration Rewards','Q Learning Rewards']).set_ylim(-50, 100)
#df_time.plot(y=['Value Iteration Time','Policy Iteration Time','Q Learning Time']).set_ylim(-10, 700)
#df_action.plot(y=['Value Iteration Action','Policy Iteration Action','Q Learning Action']).set_ylim(0, 300)
p1 = df.plot(y=['Value Iteration Reward','Policy Iteration Reward','Q Learning Reward'])
#p1.set_ylim(0, 100)
#p1.set_xlim(0, 200)
#p1.set_xticklabels([1, 25, 50, 75, 100, 125, 150, 175, 200])

p2 = df_time.plot(y=['Value Iteration Time','Policy Iteration Time','Q Learning Time'])
#p2.set_ylim(-50, 500)
#p2.set_xlim(0, 200)
#p2.set_xticklabels([1, 25, 50, 75, 100, 125, 150, 175, 200])

p3 = df_action.plot(y=['Value Iteration Action','Policy Iteration Action','Q Learning Action'])
#p3.set_ylim(0, 250)
#p3.set_xlim(0, 200)
#p3.set_xticklabels([1, 25, 50, 75, 100, 125, 150, 175, 200])

# %%
p1 = hdf.plot(hdf.index, y=['Value Iteration Reward','Policy Iteration Reward','Q Learning Reward'])
p1.set_ylim(-500, 100)
p1.set_xlim(0, 200)
p1.set_xticklabels([1, 25, 50, 75, 100, 125, 150, 175, 200])
p2 = hdf_time.plot(y=['Value Iteration Time','Policy Iteration Time','Q Learning Time'])
p2.set_ylim(-50, 1200)
p2.set_xlim(0, 200)
p2.set_xticklabels([1, 25, 50, 75, 100, 125, 150, 175, 200])
p3 = hdf_action.plot(y=['Value Iteration Action','Policy Iteration Action','Q Learning Action'])
p3.set_ylim(0, 1000)
p3.set_xlim(0, 200)
p3.set_xticklabels([1, 25, 50, 75, 100, 125, 150, 175, 200])

# %%
#hardest_q = pd.Series([1038,621,898,620,692,159,255,253,111,264,145,381,182,122,81,143,176,76,133,155,113,77,72,67,292,129,115,76,78,43,94,157,945,117,100,91,148,135,69,98,48,154,266,265,100,74,105,59,65,62,68,258,90,68,54,113,211,109,90,91,74,183,279,56,59,62,62,42,130,73,81,44,88,63,78,57,65,49,48,63,74,198,113,422,169,57,99,125,130,58,60,164,84,53,58,173,71,135,72,126])
#hardest_q_ms = pd.Series([439,147,58,59,22,38,37,32,24,23,25,49,58,33,32,31,25,31,35,75,81,55,36,36,43,31,33,42,92,92,34,29,35,50,45,37,36,51,52,44,38,44,44,35,48,39,48,47,43,39,47,48,62,40,45,43,60,48,45,44,49,51,43,56,55,51,53,57,59,61,46,58,64,63,53,58,59,60,53,57,54,65,61,65,65,63,53,66,71,60,64,60,59,67,63,67,70,54,68,66])

#hardest_q.plot()

# %%
#pivot_ui(df)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
#import pandas as pd
data = pd.DataFrame()
df1 = pd.read_csv('Easy Value.csv')
#df['file'] = file
data = pd.concat([data, df1])
df2 = pd.read_csv('Easy Policy.csv')
#df['file'] = file
data = pd.concat([data, df2])
data.to_csv('data')

data.plot()

#LABELS = ["real", "user", "sys"]

#plt.title('Time Taken by Classifier')
#plt.xlabel('Time_Types')
#plt.ylabel('Time_Value in (sec)')


#data.boxplot(by='file')

#plt.show()
